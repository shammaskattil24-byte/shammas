# %% [markdown]
# # APPTITUDE #
# 1)A  ,
# 2)C  ,
# 3)B  ,
# 4)C  ,
# 5)C  ,
# 6)B

# %% [markdown]
# # Part B – Logical Reasoning #

# %% [markdown]
# 7)C
# 8)D
# 9)B
# 10)A
# 11)B

# %% [markdown]
# # Part C – Data Interpretation #

# %% [markdown]
# 12)D
# 13)C
# 14)C
# 15)B

# %% [markdown]
# # Part D – Analytical Reasoning #

# %% [raw]
# 16)B
# 17)C
# 18)B
# 19)C
# 20)B

# %% [markdown]
#   # Part E – Python & Data Analytics Fundamentals   #

# %% [raw]
# 21)C
# 22)C
# 23)B
# 24)A
# 25)c

# %% [markdown]
# # Logical Problem: Hollow Square Pattern  #

# %%
size=5
for r in range(size):
	for c in range(size):
		if r == 0 or r ==size-1 or c==0 or c==size-1:
			print("*",end="")
		else:
			print(" ",end="")
	print()
# Out:
# *****
# *   *
# *   *
# *   *
# *****

# %% [markdown]
# #  SECTION C – MACHINE TEST

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\Shamm\Downloads\DA_Month2_EDA_Machine_Test_Dataset.csv")

# %%
df.head()
# Out:
#    Order_ID  Order_Date Region         Category      Product Customer_Segment  \
# 0  ORD10001  2025-04-10   West  Office Supplies  File Folder      Home Office
# 1  ORD10002  2025-08-24  North        Furniture        Table         Consumer
# 2  ORD10003  2025-12-30   East  Office Supplies      Pen Set         Consumer
# 3  ORD10004  2025-09-22  South      Electronics     Keyboard         Consumer
# 4  ORD10005  2025-12-26   West         Clothing        Shoes        Corporate
#
#    Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         8       27.62      0.20   176.76    Net Banking
# 1         6      595.56      0.20  2858.69           Cash
# 2        10       38.75      0.10   348.77           Cash
# 3         7      237.81      0.05  1581.42            UPI
# 4         7      126.45      0.05   840.91            UPI

# %%
 df.shape
# Out:
# (1215, 11)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1215 entries, 0 to 1214
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1215 non-null   str
#  1   Order_Date        1215 non-null   str
#  2   Region            1205 non-null   str
#  3   Category          1215 non-null   str
#  4   Product           1215 non-null   str
#  5   Customer_Segment  1205 non-null   str
#  6   Quantity          1215 non-null   int64
#  7   Unit_Price        1215 non-null   float64
#  8   Discount          1215 non-null   float64
#  9   Sales             1215 non-null   float64
#  10  Payment_Method    1200 non-null   str
# dtypes: float64(3), int64(1), str(7)
# memory usage: 104.5 KB

# %%
df.dtypes
# Out:
# Order_ID                str
# Order_Date              str
# Region                  str
# Category                str
# Product                 str
# Customer_Segment        str
# Quantity              int64
# Unit_Price          float64
# Discount            float64
# Sales               float64
# Payment_Method          str
# dtype: object

# %%
df.head()
# Out:
#    Order_ID  Order_Date Region         Category      Product Customer_Segment  \
# 0  ORD10001  2025-04-10   West  Office Supplies  File Folder      Home Office
# 1  ORD10002  2025-08-24  North        Furniture        Table         Consumer
# 2  ORD10003  2025-12-30   East  Office Supplies      Pen Set         Consumer
# 3  ORD10004  2025-09-22  South      Electronics     Keyboard         Consumer
# 4  ORD10005  2025-12-26   West         Clothing        Shoes        Corporate
#
#    Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         8       27.62      0.20   176.76    Net Banking
# 1         6      595.56      0.20  2858.69           Cash
# 2        10       38.75      0.10   348.77           Cash
# 3         7      237.81      0.05  1581.42            UPI
# 4         7      126.45      0.05   840.91            UPI

# %%
df.isnull() .sum()
# Out:
# Order_ID             0
# Order_Date           0
# Region              10
# Category             0
# Product              0
# Customer_Segment    10
# Quantity             0
# Unit_Price           0
# Discount             0
# Sales                0
# Payment_Method      15
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(15)

# %%
categorical_columns = ["Region","Category","Product","Customer_Segment","Payment_Method"]

# %%
for col in categorical_columns:
    print( col)
    print(df[col].unique())
# Out:
# Region
# <StringArray>
# ['West', 'North', 'East', 'South', nan, 'south', 'West ', ' SOUTH']
# Length: 8, dtype: str
# Category
# <StringArray>
# ['Office Supplies', 'Furniture', 'Electronics', 'Clothing']
# Length: 4, dtype: str
# Product
# <StringArray>
# [  'File Folder',         'Table',       'Pen Set',      'Keyboard',
#          'Shoes',         'Jeans',     'Bookshelf',      'Notebook',
#  'Printer Paper',       'T-Shirt',    'Headphones',       'Monitor',
#         'Jacket',        'Laptop',         'Chair',          'Desk']
# Length: 16, dtype: str
# Customer_Segment
# <StringArray>
# ['Home Office', 'Consumer', 'Corporate', nan]
# Length: 4, dtype: str
# Payment_Method
# <StringArray>
# ['Net Banking', 'Cash', 'UPI', 'Credit Card', 'Debit Card', nan]
# Length: 6, dtype: str

# %%
for col in categorical_columns:
    print("\n", col)
    print(df[col].value_counts(dropna=False))
# Out:
#  Region
# Region
# South     321
# East      296
# West      292
# North     284
# NaN        10
#  SOUTH      5
# West        4
# south       3
# Name: count, dtype: int64
#
#  Category
# Category
# Electronics        340
# Furniture          324
# Office Supplies    284
# Clothing           267
# Name: count, dtype: int64
#
#  Product
# Product
# Monitor          93
# Laptop           91
# Chair            89
# Table            83
# Notebook         81
# Keyboard         80
# Bookshelf        78
# Headphones       76
# Desk             74
# Jacket           71
# File Folder      70
# Pen Set          68
# Shoes            68
# Printer Paper    65
# Jeans            64
# T-Shirt          64
# Name: count, dtype: int64
#
#  Customer_Segment
# Customer_Segment
# Consumer       411
# Corporate      398
# Home Office    396
# NaN             10
# Name: count, dtype: int64
#
#  Payment_Method
# Payment_Method
# UPI            255
# Debit Card     247
# Net Banking    240
# ...

# %%
df["Order_Date"] = pd.to_datetime(
    df["Order_Date"],
    errors="coerce")

# %%
df.dtypes
# Out:
# Order_ID                       str
# Order_Date          datetime64[us]
# Region                         str
# Category                       str
# Product                        str
# Customer_Segment               str
# Quantity                     int64
# Unit_Price                 float64
# Discount                   float64
# Sales                      float64
# Payment_Method                 str
# dtype: object

# %%
df=df.drop_duplicates()

# %%
print (df.duplicated().sum())
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_ID          1200 non-null   str
#  1   Order_Date        1200 non-null   datetime64[us]
#  2   Region            1190 non-null   str
#  3   Category          1200 non-null   str
#  4   Product           1200 non-null   str
#  5   Customer_Segment  1190 non-null   str
#  6   Quantity          1200 non-null   int64
#  7   Unit_Price        1200 non-null   float64
#  8   Discount          1200 non-null   float64
#  9   Sales             1200 non-null   float64
#  10  Payment_Method    1185 non-null   str
# dtypes: datetime64[us](1), float64(3), int64(1), str(6)
# memory usage: 103.3 KB

# %%
df1 = df.select_dtypes(include=np.number).columns

for col in df1:
    sns.boxplot(x=df[col])
    plt.title(f"Boxplot of {col}")
    plt.show()

# %%
df.shape
df.isnull().sum()
df.duplicated().sum()
df.dtypes
# Out:
# Order_ID                       str
# Order_Date          datetime64[us]
# Region                         str
# Category                       str
# Product                        str
# Customer_Segment               str
# Quantity                     int64
# Unit_Price                 float64
# Discount                   float64
# Sales                      float64
# Payment_Method                 str
# dtype: object

# %%
total_sales = df["Sales"].sum()
print(total_sales)
# Out:
# 1831811.51

# %%
average_sales = df["Sales"].mean()
print( average_sales)
# Out:
# 1526.5095916666667

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales)
# Out:
# Category
# Electronics        977969.39
# Furniture          543227.84
# Clothing           204058.41
# Office Supplies    106555.87
# Name: Sales, dtype: float64

# %%
sns.barplot(data=df, x="Category", y="Sales", color="red",errorbar=None)
plt.title("Sales Category")
plt.xlabel("Category",color="blue")
plt.ylabel("Sales",color="blue")
plt.show()

# %% [markdown]
# # Sales by Region

# %%
df1= df.groupby("Region")["Sales"].sum()
plt.pie(df1,labels=df1.index,autopct="%1.1f%%")
plt.title("Sales by Region")
plt.show()

# %% [markdown]
# # sales Distribution

# %%
plt.hist(df["Sales"], bins=20)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")

plt.show()

# %%
monthly = df.groupby("Order_Date", as_index=False)["Sales"].sum()

# %%
monthly = df.groupby(
    "Order_Date",
    as_index=False
)["Sales"].sum()

plt.figure(figsize=(12, 6))

plt.plot(
    monthly["Order_Date"],
    monthly["Sales"],
    marker="o",
    color="red"
)

plt.grid()
plt.title("Monthly Sales Trend")
plt.xlabel("Order Date")
plt.ylabel("Sales")
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)
print(category_sales.max())
# Out:
# 977969.39

# %%
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

print("Sales by Product:")
print(product_sales)

print("\nHighest Sales Product:")
print(product_sales.idxmax())

print("Highest Product Sales:")
print(product_sales.max())
# Out:
# Sales by Product:
# Product
# Keyboard         278256.25
# Headphones       239589.24
# Laptop           230825.42
# Monitor          229298.48
# Chair            153672.26
# Desk             138966.58
# Bookshelf        138153.47
# Table            112435.53
# Shoes             55094.04
# Jeans             53076.97
# Jacket            51906.74
# T-Shirt           43980.66
# Pen Set           29012.72
# Notebook          27013.89
# Printer Paper     25996.74
# File Folder       24532.52
# Name: Sales, dtype: float64
#
# Highest Sales Product:
# Keyboard
# Highest Product Sales:
# 278256.25

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)

# %%
print("Sales by Region:")
print(region_sales)
# Out:
# Sales by Region:
# Region
# West      488184.71
# South     477130.01
# East      435049.42
# North     406977.11
#  SOUTH     12348.13
# West        3600.54
# south       2476.93
# Name: Sales, dtype: float64

# %%
print("\nBest Performing Region:")
print(region_sales.idxmax())
# Out:
# Best Performing Region:
# West

# %%
print("Best Region Sales:")
print(region_sales.max())
# Out:
# Best Region Sales:
# 488184.71

# %%
print("\nWorst Performing Region:")
print(region_sales.idxmin())
# Out:
# Worst Performing Region:
# south

# %%
print("Worst Region Sales:")
print(region_sales.min())
# Out:
# Worst Region Sales:
# 2476.93

# %%
segment_sales = df.groupby("Customer_Segment")["Sales"].sum().sort_values(
    ascending=False
)
print(segment_sales)
# Out:
# Customer_Segment
# Consumer       649672.00
# Corporate      625863.84
# Home Office    544089.40
# Name: Sales, dtype: float64

# %%
best_segment = segment_sales.idxmax()

# %%
print("\nTop Customer Segment:", best_segment)
print("Total Sales:", segment_sales.max())
# Out:
# Top Customer Segment: Consumer
# Total Sales: 649672.0

# %%
print(df.columns.tolist())
# Out:
# ['Order_ID', 'Order_Date', 'Region', 'Category', 'Product', 'Customer_Segment', 'Quantity', 'Unit_Price', 'Discount', 'Sales', 'Payment_Method']

# %%
if "Profit" in df.columns:
    print("Profit column is available.")
else:
    print("Profit column is NOT available.")
# Out:
# Profit column is NOT available.

# %%
df["Order_Date"] = pd.to_datetime(
    df["Order_Date"],
    errors="coerce"
)

# %%
discount_sales_corr = df[
    ["Discount", "Sales"]
].corr()

print(discount_sales_corr)
# Out:
#           Discount     Sales
# Discount  1.000000 -0.024163
# Sales    -0.024163  1.000000

# %%
correlation_value = df["Discount"].corr(
    df["Sales"]
)

print("Discount-Sales Correlation:", correlation_value)
# Out:
# Discount-Sales Correlation: -0.024163109791013

# %%
discount_analysis = df.groupby(
    "Discount"
)["Sales"].agg(
    ["sum", "mean", "count"]
)

print(discount_analysis)
# Out:
#                 sum         mean  count
# Discount
# 0.00      361870.57  1526.880042    237
# 0.05      341402.70  1595.339720    214
# 0.10      421252.25  1685.009000    250
# 0.15      345645.92  1366.189407    253
# 0.20      361640.07  1470.081585    246

# %%
plt.figure(figsize=(8, 5))

sns.scatterplot(
    data=df,
    x="Discount",
    y="Sales"
)

plt.title("Discount vs Sales")
plt.xlabel("Discount")
plt.ylabel("Sales")

plt.show()

# %%
Q1 = df["Sales"].quantile(0.25)
Q3 = df["Sales"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

sales_outliers = df[
    (df["Sales"] < lower_limit) |
    (df["Sales"] > upper_limit)
]

print("Number of Sales Outliers:", len(sales_outliers))
# Out:
# Number of Sales Outliers: 117
