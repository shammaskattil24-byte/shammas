# %% [markdown]
# # Machine test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Shamm\Downloads\DA_Month2_EDA_Machine_Test_Dataset (1).csv")
df
# Out:
#       Order_ID  Order_Date Region         Category      Product  \
# 0     ORD10001  2025-04-10   West  Office Supplies  File Folder
# 1     ORD10002  2025-08-24  North        Furniture        Table
# 2     ORD10003  2025-12-30   East  Office Supplies      Pen Set
# 3     ORD10004  2025-09-22  South      Electronics     Keyboard
# 4     ORD10005  2025-12-26   West         Clothing        Shoes
# ...        ...         ...    ...              ...          ...
# 1210  ORD10088  2025-11-05  North        Furniture         Desk
# 1211  ORD10942  2025-08-24   West        Furniture        Table
# 1212  ORD10191  2025-05-09  South         Clothing      T-Shirt
# 1213  ORD10859  2025-01-19   East  Office Supplies     Notebook
# 1214  ORD11137  2025-11-25   West        Furniture        Table
#
#      Customer_Segment  Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         Home Office         8       27.62      0.20   176.76    Net Banking
# ...

# %% [markdown]
# # Part A Data Understanding & Cleaning

# %%
print(df.shape)
# Out:
# (1215, 11)

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Order_Date', 'Region', 'Category', 'Product',
#        'Customer_Segment', 'Quantity', 'Unit_Price', 'Discount', 'Sales',
#        'Payment_Method'],
#       dtype='str')

# %%
df.head()
# Out:
#    Order_ID  Order_Date Region         Category      Product Customer_Segment  \
# 0  ORD10001  2025-04-10   West  Office Supplies  File Folder      Home Office
# 1  ORD10002  2025-08-24  North        Furniture        Table         Consumer
# 2  ORD10003  2025-12-30   East  Office Supplies      Pen Set         Consumer
# 3  ORD10004  2025-09-22  South      Electronics     Keyboard         Consumer
# 4  ORD10005  2025-12-26   West         Clothing        Shoes        Corporate
#
#    Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         8       27.62      0.20   176.76    Net Banking
# 1         6      595.56      0.20  2858.69           Cash
# 2        10       38.75      0.10   348.77           Cash
# 3         7      237.81      0.05  1581.42            UPI
# 4         7      126.45      0.05   840.91            UPI

# %%
df.tail()
# Out:
#       Order_ID  Order_Date Region         Category   Product Customer_Segment  \
# 1210  ORD10088  2025-11-05  North        Furniture      Desk        Corporate
# 1211  ORD10942  2025-08-24   West        Furniture     Table      Home Office
# 1212  ORD10191  2025-05-09  South         Clothing   T-Shirt         Consumer
# 1213  ORD10859  2025-01-19   East  Office Supplies  Notebook         Consumer
# 1214  ORD11137  2025-11-25   West        Furniture     Table         Consumer
#
#       Quantity  Unit_Price  Discount    Sales Payment_Method
# 1210         4      554.88      0.20  1775.62     Debit Card
# 1211         1       36.88      0.10    33.19    Credit Card
# 1212         6       44.11      0.00   264.68    Credit Card
# 1213         8      116.54      0.00   932.33    Net Banking
# 1214         7       51.23      0.15   304.85    Credit Card

# %%
print(df.dtypes)
# Out:
# Order_ID                str
# Order_Date              str
# Region                  str
# Category                str
# Product                 str
# Customer_Segment        str
# Quantity              int64
# Unit_Price          float64
# Discount            float64
# Sales               float64
# Payment_Method          str
# dtype: object

# %%
print(df.isnull().sum())
# Out:
# Order_ID             0
# Order_Date           0
# Region              10
# Category             0
# Product              0
# Customer_Segment    10
# Quantity             0
# Unit_Price           0
# Discount             0
# Sales                0
# Payment_Method      15
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 15

# %%
print(df.nunique())
# Out:
# Order_ID            1200
# Order_Date           349
# Region                 7
# Category               4
# Product               16
# Customer_Segment       3
# Quantity              13
# Unit_Price          1185
# Discount               5
# Sales               1197
# Payment_Method         5
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# # part B

# %%
print(df["Category"].unique())
print(df["Region"].unique())
print(df["Product"].unique())
print(df["Customer_Segment"].unique())
print(df["Payment_Method"].unique())
# Out:
# <StringArray>
# ['Office Supplies', 'Furniture', 'Electronics', 'Clothing']
# Length: 4, dtype: str
# <StringArray>
# ['West', 'North', 'East', 'South', nan, 'south', 'West ', ' SOUTH']
# Length: 8, dtype: str
# <StringArray>
# [  'File Folder',         'Table',       'Pen Set',      'Keyboard',
#          'Shoes',         'Jeans',     'Bookshelf',      'Notebook',
#  'Printer Paper',       'T-Shirt',    'Headphones',       'Monitor',
#         'Jacket',        'Laptop',         'Chair',          'Desk']
# Length: 16, dtype: str
# <StringArray>
# ['Home Office', 'Consumer', 'Corporate', nan]
# Length: 4, dtype: str
# <StringArray>
# ['Net Banking', 'Cash', 'UPI', 'Credit Card', 'Debit Card', nan]
# Length: 6, dtype: str

# %%
df=df.drop_duplicates()
df
# Out:
#       Order_ID  Order_Date Region         Category      Product  \
# 0     ORD10001  2025-04-10   West  Office Supplies  File Folder
# 1     ORD10002  2025-08-24  North        Furniture        Table
# 2     ORD10003  2025-12-30   East  Office Supplies      Pen Set
# 3     ORD10004  2025-09-22  South      Electronics     Keyboard
# 4     ORD10005  2025-12-26   West         Clothing        Shoes
# ...        ...         ...    ...              ...          ...
# 1195  ORD11196  2025-01-18  North         Clothing       Jacket
# 1196  ORD11197  2025-12-17   East      Electronics      Monitor
# 1197  ORD11198  2025-08-07  North        Furniture        Chair
# 1198  ORD11199  2025-07-18  South         Clothing       Jacket
# 1199  ORD11200  2025-09-16  South  Office Supplies  File Folder
#
#      Customer_Segment  Quantity  Unit_Price  Discount    Sales Payment_Method
# 0         Home Office         8       27.62      0.20   176.76    Net Banking
# ...

# %%
df["Region"]=df["Region"].fillna("Unknown")
df["Region"]
# Out:
# 0        West
# 1       North
# 2        East
# 3       South
# 4        West
#         ...
# 1195    North
# 1196     East
# 1197    North
# 1198    South
# 1199    South
# Name: Region, Length: 1200, dtype: str

# %%
df["Customer_Segment"]=df["Customer_Segment"].fillna("Unknown")
df["Customer_Segment"]
# Out:
# 0       Home Office
# 1          Consumer
# 2          Consumer
# 3          Consumer
# 4         Corporate
#            ...
# 1195       Consumer
# 1196       Consumer
# 1197       Consumer
# 1198       Consumer
# 1199    Home Office
# Name: Customer_Segment, Length: 1200, dtype: str

# %%
df["Payment_Method"]=df["Payment_Method"].fillna("Unknown")
df["Payment_Method"]
# Out:
# 0       Net Banking
# 1              Cash
# 2              Cash
# 3               UPI
# 4               UPI
#            ...
# 1195    Credit Card
# 1196     Debit Card
# 1197     Debit Card
# 1198           Cash
# 1199     Debit Card
# Name: Payment_Method, Length: 1200, dtype: str

# %%
df.describe()
# Out:
#           Quantity   Unit_Price     Discount         Sales
# count  1200.000000  1200.000000  1200.000000   1200.000000
# mean      5.749167   299.202858     0.102375   1526.509592
# std       4.611830   280.660390     0.070685   2032.082985
# min       1.000000     5.770000     0.000000      7.060000
# 25%       3.000000    94.452500     0.050000    338.490000
# 50%       6.000000   191.140000     0.100000    763.430000
# 75%       8.000000   444.797500     0.150000   1888.360000
# max      60.000000  1175.950000     0.200000  27688.500000

# %%
df.shape
# Out:
# (1200, 11)

# %%
df.isnull().sum()
# Out:
# Order_ID            0
# Order_Date          0
# Region              0
# Category            0
# Product             0
# Customer_Segment    0
# Quantity            0
# Unit_Price          0
# Discount            0
# Sales               0
# Payment_Method      0
# dtype: int64

# %%
df["Sales"].sum()
# Out:
# np.float64(1831811.51)

# %%
df2=df.groupby("Category")["Sales"].sum()
df2.idxmax()
# Out:
# 'Electronics'

# %%
df2.idxmin()
# Out:
# 'Office Supplies'

# %%
df.groupby("Sales")["Region"].sum()
# Out:
# Sales
# 7.06         East
# 11.48        West
# 11.94       North
# 13.88       South
# 16.70        East
#             ...
# 9034.83     North
# 10456.82     East
# 14656.00     East
# 22315.90    South
# 27688.50     West
# Name: Region, Length: 1197, dtype: str

# %%
print(df[["Quantity","Unit_Price","Discount","Sales"]].describe())
# Out:
#           Quantity   Unit_Price     Discount         Sales
# count  1200.000000  1200.000000  1200.000000   1200.000000
# mean      5.749167   299.202858     0.102375   1526.509592
# std       4.611830   280.660390     0.070685   2032.082985
# min       1.000000     5.770000     0.000000      7.060000
# 25%       3.000000    94.452500     0.050000    338.490000
# 50%       6.000000   191.140000     0.100000    763.430000
# 75%       8.000000   444.797500     0.150000   1888.360000
# max      60.000000  1175.950000     0.200000  27688.500000

# %%
print(df[["Quantity","Unit_Price","Discount","Sales"]].corr())
# Out:
#             Quantity  Unit_Price  Discount     Sales
# Quantity    1.000000   -0.010444  0.029076  0.532191
# Unit_Price -0.010444    1.000000 -0.016025  0.687052
# Discount    0.029076   -0.016025  1.000000 -0.024163
# Sales       0.532191    0.687052 -0.024163  1.000000

# %%
Category_sales = df.groupby("Category")["Sales"].sum()
plt.bar(Category_sales.index, Category_sales.values,color=["green"])
plt.xlabel("Category")
plt.ylabel("Total sales")
plt.title("Sales by Category")
plt.xticks(rotation=45)
plt.show()

# %%
Product_sales = df.groupby("Product")["Sales"].sum()
plt.bar(Product_sales.index,Product_sales.values)
plt.xlabel("Product")
plt.ylabel("Total sales")
plt.title("sales by Product ")
plt.xticks(rotation=45)
plt.show()

# %%
Segment_sales = df.groupby("Customer_Segment")["Sales"].sum()
plt.bar(Segment_sales.index,Segment_sales.values)
plt.xlabel("Customer_Segment")
plt.ylabel("Total sales")
plt.title("sales by Customer_Segment ")
plt.xticks(rotation=45)
plt.show()

# %%
plt.hist(df["Sales"],bins=10)
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.title("Sales Distribution")
plt.grid()
plt.show()

# %%
sns.boxplot(
    x="Category",
    y="Sales",
    data=df
)
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
Product= df["Product"].value_counts()

plt.pie(
    Product.values,
    labels=Product.index,
    autopct="%1.1f%%"
)

plt.title("Product Distribution")
plt.show()

# %%
Region= df["Region"].value_counts()

plt.pie(
    Region.values,
    labels=Region.index,
    autopct="%1.1f%%"
)

plt.title("Region Distribution")
plt.show()

# %%
Region= df["Region"].value_counts()

plt.pie(
    Region.values,
    labels=Region.index,
    autopct="%1.1f%%"
)

plt.title("Region Distribution")
plt.show()

# %%
Sales_count = df.groupby("Discount")["Sales"].value_counts().sort_index()

plt.plot(
    Sales_count.index,
    Sales_count.values,
    marker="o"
)

plt.title("discount by Sales")
plt.xlabel("Sales")
plt.ylabel("Discount")

plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# TypeError: float() argument must be a string or a real number, not 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 Sales_count = df.groupby("Discount")["Sales"].value_counts().sort_index()
#       2
# ----> 3 plt.plot(
#       4     Sales_count.index,
#       5     Sales_count.values,
#       6     marker="o"
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
# ...

# %%
PART - C BUSINESS REQUIREMENTS

1 Highest sales category is Electronics Highest sales product is keyboard Highest sales product is Consumer

2-Best-south worst-north

3-customer segment contributes the most to the business is consumer

4-Generate highest profit category is Electronics

7-all the category have outlier 8-focus more on high performing electronics product improve sales performance in the north region avoid un necessary discounts because discound has little
