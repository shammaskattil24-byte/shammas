# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel(r"C:\Users\Shamm\Downloads\d4bdb23b-4858-482e-9d51-d9fa09faeec4.xlsx")
df
# Out:
#    Month  Sales  Profit  Customers  Marketing_Spend  Returns
# 0    Jan    120      20         80               15        5
# 1    Feb    145      25         95               18        6
# 2    Mar    135      22         90               17        4
# 3    Apr    170      30        110               20        7
# 4    May    190      35        125               22        8
# 5    Jun    210      40        140               25        9
# 6    Jul    225      43        150               27       10
# 7    Aug    240      48        165               30        8
# 8    Sep    230      45        155               28        7
# 9    Oct    260      52        175               32        9
# 10   Nov    280      58        190               35       11
# 11   Dec    310      65        210               40       12

# %%
plt.plot(df["Month"],df["Sales"],marker="o")
plt.title("Monthly Sales")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
plt.bar(df["Month"],df["Profit"])
plt.title("Monthly Profit")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.show()

# %%
plt.scatter(df["Marketing_Spend"],df["Sales"])
plt.title("Marketing Spend vs Sales")
plt.xlabel("Marketing Spend")
plt.ylabel("Sales")
plt.grid(True)
plt.show()

# %%
plt.hist(df['Sales'], bins=6)
plt.title('Distribution of Sales')
plt.xlabel('Sales')
plt.ylabel('Frequency')
plt.show()

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 8))


ax[0, 0].plot(df['Month'], df['Sales'], marker='o')
ax[0, 0].set_title('Monthly Sales')
ax[0, 0].set_xlabel('Month')
ax[0, 0].set_ylabel('Sales')
ax[0, 0].grid(True)


ax[0, 1].bar(df['Month'], df['Profit'])
ax[0, 1].set_title('Monthly Profit')
ax[0, 1].set_xlabel('Month')
ax[0, 1].set_ylabel('Profit')


ax[1, 0].scatter(df['Marketing_Spend'], df['Sales'])
ax[1, 0].set_title('Marketing Spend vs Sales')
ax[1, 0].set_xlabel('Marketing Spend')
ax[1, 0].set_ylabel('Sales')
ax[1, 0].grid(True)


ax[1, 1].plot(df['Month'], df['Customers'], marker='o')
ax[1, 1].set_title('Monthly Customers')
ax[1, 1].set_xlabel('Month')
ax[1, 1].set_ylabel('Customers')
ax[1, 1].grid(True)

plt.tight_layout()
plt.show()
